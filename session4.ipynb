# %%
import cv2

# Load the image
image = cv2.imread('input.jpg')

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Save the grayscale image
cv2.imwrite('output_grayscale.jpg', gray_image)

# %%
import cv2

# Input and output video paths
input_video = "input.mp4"  # Replace with your input video file path
output_video = "output_gray.mp4"  # Replace with your desired output path

# Open the input video
cap = cv2.VideoCapture(input_video)
if not cap.isOpened():
    print(f"Error: Could not open video file: {input_video}")
else:
    # Get video properties
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4
    out = cv2.VideoWriter(output_video, fourcc, fps, (frame_width, frame_height), isColor=False)

    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret:
            # Convert to grayscale
            gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

            # Write the grayscale frame
            out.write(gray_frame)
        else:
            break

    # Release resources
    cap.release()
    out.release()
    cv2.destroyAllWindows()

    print(f"Video converted to grayscale and saved at: {output_video}")

# %%
import cv2

# Input and output video paths
input_video = "input.mp4"  # Replace with your input video file path
output_video = "output_gray.mp4"  # Replace with your desired output path

# Open the input video
cap = cv2.VideoCapture(input_video)
if not cap.isOpened():
    print(f"Error: Could not open video file: {input_video}")
else:
    # Get video properties
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4
    out = cv2.VideoWriter(output_video, fourcc, fps, (frame_width, frame_height), isColor=False)

    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret:
            # Convert to grayscale
            gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

            # Write the grayscale frame
            out.write(gray_frame)
        else:
            break

    # Release resources
    cap.release()
    out.release()
    cv2.destroyAllWindows()

    print(f"Video converted to grayscale and saved at: {output_video}")

# %%
import cv2
import numpy as np
import time

# Define video properties
frame_width = 640
frame_height = 480
frame_rate = 2  # Frames per second
video_filename = "presentation2.avi"

# Define codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(video_filename, fourcc, frame_rate, (frame_width, frame_height))

# List of colors for different frames
colors = [(0, 0, 0), (255, 0, 0), (0, 255, 0), (0, 0, 255)]  # Black, Blue, Green, Red

for i, color in enumerate(colors):
    # Create an image with the selected color
    frame = np.zeros((frame_height, frame_width, 3), dtype=np.uint8)
    frame[:] = color  # Fill frame with color

    # Draw shapes and text
    cv2.putText(frame, f"Slide {i+1}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    cv2.rectangle(frame, (100, 100), (300, 300), (255, 255, 255), 2)
    cv2.circle(frame, (450, 200), 50, (255, 255, 255), 2)
    cv2.line(frame, (50, 400), (590, 400), (255, 255, 255), 2)
    
    # Write the frame to the video
    out.write(frame)
    
    # Display the frame (optional)
    cv2.imshow('Presentation', frame)
    cv2.waitKey(1000)  # Wait for 1 second

# Release everything when done
out.release()
cv2.destroyAllWindows()

print(f"Video saved as {video_filename}")

# %% [markdown]
#  List of colors for different frames
# colors = [(0, 0, 0), (255, 0, 0), (0, 255, 0), (0, 0, 255)]  # Black, Blue, Green, Red
